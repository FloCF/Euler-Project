# %% [markdown]
# # Problem 44
#
# Pentagonal numbers are generated by the formula, $P_n=n(3n−1)/2$. The first ten pentagonal numbers are:
#
# $$
# 1, 5, 12, 22, 35, 51, 70, 92, 117, 145, ...
# $$
#
# It can be seen that $P_4 + P_7 = 22 + 70 = 92 = P_8$. However, their difference, $70 − 22 = 48$, is not pentagonal.
#
# Find the pair of pentagonal numbers, $P_j$ and $P_k$, for which their sum and difference are pentagonal and $D = |P_k − P_j|$ is minimised; what is the value of $D$?

# %%
from numpy import array
import time

max_number= 10000

pentas = array([int(n*(3*n-1)/2) for n in range(1,max_number+1)])
penta_pair = []
start = time.clock()
for i, penta1 in enumerate(pentas):
    for j in range(i):
        if any(penta1+pentas[j]==pentas) and any(penta1-pentas[j]==pentas):
            penta_pair += [[penta1,pentas[j]]]
            print("Penta_Pair: " + str(penta_pair[-1]))
    if (i+1)%100==0:
        stop = time.clock()
        print("Checking " + str(i) + " ...still searching, time for 100 rounds : " + str(stop-start))
        start = time.clock()
# Out:
# Checking 99 ...still searching, time for 100 rounds : 0.9321620000009716
# Checking 199 ...still searching, time for 100 rounds : 2.844003000000157
# Checking 299 ...still searching, time for 100 rounds : 4.6386229999989155
# Checking 399 ...still searching, time for 100 rounds : 6.397560999999769
# Checking 499 ...still searching, time for 100 rounds : 8.289359000000331
# Checking 599 ...still searching, time for 100 rounds : 10.25970800000141
# Checking 699 ...still searching, time for 100 rounds : 11.88788299999942
# Checking 799 ...still searching, time for 100 rounds : 13.726553999998941
# Checking 899 ...still searching, time for 100 rounds : 15.78536300000087
# Checking 999 ...still searching, time for 100 rounds : 17.497363999998925
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-6285e48d9bf6> in <module>()
# ...
